# %% [markdown]
# <a href="https://colab.research.google.com/github/HARBAL-DEEP-SIHU/SENTIMENTAL-ANALYSIS/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 6.7MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vaderSentiment) (3.0.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
vs = SentimentIntensityAnalyzer()

# %%
text = 'you are  awesome'
vs.polarity_scores(text)
# Out:
# {'compound': 0.6249, 'neg': 0.0, 'neu': 0.328, 'pos': 0.672}

# %%
text2 = '10/10 to good battery '
vs.polarity_scores(text2)
# Out:
# {'compound': 0.4404, 'neg': 0.0, 'neu': 0.508, 'pos': 0.492}

# %%
text3 = 'The ball was quite good but is somewhat hard to play and the color was awesome I ordered in Flipkart for first time they gave their best and ekart delivered the ball at 12:30 am they did it correctly on time'
vs.polarity_scores(text3)
# Out:
# {'compound': 0.9523, 'neg': 0.022, 'neu': 0.674, 'pos': 0.304}

# %%
# Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %%
url = 'https://inshorts.com/en/read/sports'
news_data = []
news_category = url.split('/')[-1]
data = requests.get(url)
soup = BeautifulSoup(data.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <style>
#     /* The Modal (background) */
#     .modal_contact {
#         display: none; /* Hidden by default */
#         position: fixed; /* Stay in place */
#         z-index: 8; /* Sit on top */
#         left: 0;
#         top: 0;
#         width: 100%; /* Full width */
#         height: 100%;
#         overflow: auto; /* Enable scroll if needed */
#         background-color: rgb(0,0,0); /* Fallback color */
#         background-color: rgba(0,0,0,0.4); /* Black w/ opacity */
#     }
#
#     /* Modal Content/Box */
#     .modal-content {
#         background-color: #fefefe;
#         margin: 15% auto;
#         padding: 20px !important;
#         padding-top: 0 !important;
#         /* border: 1px solid #888; */
#         text-align: center;
#         position: relative;
#         border-radius: 6px;
#     }
#
#     /* The Close Button */
#     .close {
#       left: 90%;
#       color: #aaa;
#       float: right;
#       font-size: 28px;
#       font-weight: bold;
#     /* position: absolute; */
#     /* bottom: 86%; */
#     /* display: inline-block; */
#     /* padding-left: 5%; */
#     }
#
#     .close:hover,
#     .close:focus {
#         color: black;
#         text-decoration: none;
#         cursor: pointer;
#     }
#
#     #myBtn {
#       background: #999999;
#       color: #ffffff;
#       text-transform: uppercase;
#       font-weight: bold;
#       box-shadow: none;
#       border-radius: 4px;
#       border: none;
#       font-size: .8rem;
#       /* width: 8rem; */
#       height: 2rem;
#       line-height: 2rem;
#     }
#
#     .contact {
#       margin-bottom: 4%;
#       clear: both;
#     }
#   </style>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="manifest.json" rel="manifest"/>
# <!-- Fallback to homescreen for Chrome   <39 on Android -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="inshorts" name="application-name"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" sizes="192x192"/>
# <!-- Add to homescreen for Safari on iOS -->
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="inshorts" name="apple-mobile-web-app-title"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-icon"/>
# <!-- Tile icon for Win8 (144x144 + tile color) -->
# <meta content="fav/favicon.png" name="msapplication-TileImage"/>
# <meta content="#424242" name="msapplication-TileColor"/>
# <meta content="#424242" name="theme-color"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="#424242" name="msapplication-navbutton-color"/>
# <meta content="#424242" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="apple-touch-startup-image"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="app" name="twitter:card"/>
# <meta content="@inshorts" name="twitter:site"/>
# <meta content="@inshorts" name="twitter:creator"/>
# <meta content="Inshorts delivers news in less than 60 words, containing only the essential facts, compromising on anything that is close to opinionating and storytelling." name="twitter:description"/>
# <meta content="IN" name="twitter:app:country"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:iphone"/>
# <meta content="892146527" name="twitter:app:id:iphone"/>
# <meta content="nis://news" name="twitter:app:url:iphone"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:ipad"/>
# <meta content="892146527" name="twitter:app:id:ipad"/>
# <meta content="nis://news" name="twitter:app:url:ipad"/>
# <meta content="Inshorts - Stay Informed" name="twitter:app:name:googleplay"/>
# <meta content="com.nis.app" name="twitter:app:id:googleplay"/>
# <meta content="nis://news" name="twitter:app:url:googleplay"/>
# <meta content="Read sports news in English in less that 60 words and get updated with latest cricket, football, tennis and basketball in a fast and easy way with inshorts." name="description"/>
# <link href="https://inshorts.com/en/read/sports" rel="canonical"/>
# <link href="https://inshorts.com/en/read/sports" reflang="en" rel="alternate"/>
# <meta content="app-id=892146527" name="apple-itunes-app"/>
# <meta content="app-id=com.nis.app" name="google-play-app"/>
# <title>Sports News: Cricket News, Football News &amp; Tennis News in English with Inshorts</title>
# <!-- CSS  -->
# <link href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.1/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Hind:500,600,400&amp;subset=latin,devanagari" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/main.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/index.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/read.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="/dist/styles/news-card.css" media="screen,projection" rel="stylesheet" type="text/css"/>
# <link href="https://assets.inshorts.com/website_assets/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/dist/manifest.json" rel="manifest"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     let top_banner_slot;
#   </script>
# <!-- Top banner for desktop-->
# <script>
#     googletag.cmd.push(function() {
#
#
#         //Top banner for desktop
#         top_banner_slot = googletag.defineSlot('/142919096/inshorts_website_728x90', [728, 90], 'div-gpt-ad-1536585015617-0')
#         .addService(googletag.pubads())
#         .setCollapseEmptyDiv(true,true);
#
#
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableSingleRequest();
#       googletag.enableServices();
#     });
#   </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window, document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '822966517773327');
#     fbq('track', 'PageView');
#   </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=822966517773327&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-55157535-6', 'auto');
#   ga('send', 'pageview');
# </script>
# <body>
# <!-- Begin comScore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({ c1: "2", c2: "28268321" });
#     (function() {
#       var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#       s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#       el.parentNode.insertBefore(s, el);
#     })();
#   </script>
# <noscript>
# <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=28268321&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- HEADER START -->
# <div class="header z-depth-1">
# <div class="menu clickable">
# <button class="c-hamburger c-hamburger--htx"><span>toggle menu</span></button><span class="unselectable">Menu</span>
# </div>
# <!--
#     <div class="search-wrapper hide-on-small-only">
#       <input class="search-box" placeholder="Search" id="search"/>
#       <i id="search_icon" class="material-icons search-icon">search</i>
#       <div class="search-box-ul">&nbsp;</div>
#     </div>
#     -->
# <a href="/"><img class="logo" src="https://assets.inshorts.com/website_assets/images/logo_inshorts.png"/></a>
# </div>
# <!-- HEADER END -->
# <!--SIDEBAR START -->
# <div class="hide-on-med-and-up sidebar-bg" style="display: none;"> </div>
# <div class="sidebar" style="overflow-y: scroll;">
# <div class="lang-bar" style="">
# <div class="lang-selector clickable">
# <a href="/en/read/sports"><div class="lang-en selected">English</div></a>
# <a href="/hi/read/sports"><div class="lang-hi ">हिन्दी</div></a>
# </div>
# </div>
# <div>
# <div class="category-header">Categories</div>
# <ul class="category-list">
# <a href="/en/read" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToAllNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToAllNews' });"> <li class="active-category ">All News</li> </a>
# <a href="/en/read/national" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToIndiaNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToIndiaNews' });"> <li class="active-category ">India</li> </a>
# <a href="/en/read/business" onclick="ga(" send=""> <li class="active-category ">Business</li> </a>
# <a href="/en/read/sports" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTosportsNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSportsNews' });"> <li class="active-category selected">Sports</li> </a>
# <a href="/en/read/world" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">World</li> </a>
# <a href="/en/read/politics" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToworldNews', 'eventAction': 'clicked',   'eventLabel': 'RedirectedToworldNews' });"> <li class="active-category ">Politics</li> </a>
# <a href="/en/read/technology" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTotechnologyNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTotechnologyNews' });"> <li class="active-category ">Technology</li> </a>
# <a href="/en/read/startup" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTostartupNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTostartupNews' });"> <li class="active-category ">Startup</li> </a>
# <a href="/en/read/entertainment" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToEntertainmentNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToEntertainmentNews' });"> <li class="active-category ">Entertainment</li> </a>
# <a href="/en/read/miscellaneous" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToMiscellaneousNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToMiscellaneousNews' });"> <li class="active-category ">Miscellaneous</li> </a>
# <a href="/en/read/hatke" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkTohatkeNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedTohatkeNews' });"> <li class="active-category ">Hatke</li> </a>
# <a href="/en/read/science" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToscienceNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToscienceNews' });"> <li class="active-category ">Science</li> </a>
# <a href="/en/read/automobile" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToautomobileNews', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToautomobileNews' });"> <li class="active-category ">Automobile</li> </a>
# </ul>
# </div>
# </div>
# <!--SIDEBAR END -->
# <!-- BODY START -->
# <div class="container" style="min-height:550px;">
# <div class="row" style="padding-top:110px;">
# <div id="div-gpt-ad-1536585015617-0" style="height:90px; width:728px;margin: auto; margin-bottom: 1%;">
# <script>
#           googletag.cmd.push(function() {
#             googletag.display('div-gpt-ad-1536585015617-0');
#             googletag.pubads().refresh([top_banner_slot]);
#           });
#           </script>
# </div>
# <div class="hide-on-med-and-down z-depth-1" style="margin-left : auto;margin-right : auto;margin-bottom: 32px;width : 900px;height:48px;background: #f44336">
# <div style="font-weight: 300;color:white !important;font-size:14px;margin-left: 48px;margin-top: 13px;position: absolute;display: block;">
#           For the best experience use <a href="https://inshorts.com/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#         </div>
# </div>
# <div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ipl-2021-suspended-indefinitely-bcci-vicepresident-rajeev-shukla-1620114691556" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="IPL 2021 suspended indefinitely: BCCI Vice-President Rajeev Shukla" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/4_tue/img_1620115196549_89.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/4_tue/img_1620115196549_89.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ipl-2021-suspended-indefinitely-bcci-vicepresident-rajeev-shukla-1620114691556" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'IPL%202021%20suspended%20indefinitely%3A%20BCCI%20Vice-President%20Rajeev%20Shukla)' });" style="color:#44444d!important">
# <span itemprop="headline">IPL 2021 suspended indefinitely: BCCI Vice-President Rajeev Shukla</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/ipl-2021-suspended-indefinitely-bcci-vicepresident-rajeev-shukla-1620114691556"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-05-04T07:51:31.000Z" itemprop="datePublished">01:21 pm</span> on <span clas="date">04 May 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The Indian Premier League (IPL) 2021 has been suspended indefinitely, BCCI Vice President Rajeev Shukla told ANI. This comes after several players across the eight teams tested positive for coronavirus. As per reports, the IPL 2021 could be later moved to Mumbai and resume after all the players complete their hard quarantine.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news
span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://twitter.com/mj_slats/status/1389880437523161094?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">Twitter</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/exaustralia-cricketer-macgill-kidnapped-in-sydney-girlfriends-brother-arrested-1620199363800" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="Ex-Australia cricketer MacGill kidnapped in Sydney, girlfriend's brother arrested" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/5_wed/img_1620198772974_575.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/5_wed/img_1620198772974_575.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/exaustralia-cricketer-macgill-kidnapped-in-sydney-girlfriends-brother-arrested-1620199363800" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Ex-Australia%20cricketer%20MacGill%20kidnapped%20in%20Sydney%2C%20girlfriend's%20brother%20arrested)' });" style="color:#44444d!important">
# <span itemprop="headline">Ex-Australia cricketer MacGill kidnapped in Sydney, girlfriend's brother arrested</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/exaustralia-cricketer-macgill-kidnapped-in-sydney-girlfriends-brother-arrested-1620199363800"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-05-05T07:22:43.000Z" itemprop="datePublished">12:52 pm</span> on <span clas="date">05 May 2021,Wednesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Former Australia leg-spinner Stuart MacGill was kidnapped, threatened at gunpoint and released in Sydney last month, police said. Four people, including MacGill's girlfriend's brother, have been arrested in connection with the incident which took place on 14 April. MacGill sustained minor injuries in the incident but didn't require medical care, police added.</div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/exaustralia-cricketer-macgill-kidnapped-in-sydney-girlfriends-brother-arrested-1620199363800"><span class="short">short</span></a> by <span class="author">Anmol Sharma</span> /
#       <span class="time" content="2021-05-05T07:22:43.000Z" itemprop="dateModified">12:52 pm</span> on <span class="date">05 May</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.crictracker.com/plot-twist-pops-in-stuart-macgills-kidnapping-case-girlfriends-brother-in-custody/?amp=&amp;utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'CricTracker' });" target="_blank">CricTracker</a></div>
# </div>
# </div>
# </div>
# <div id="div-gpt-ad-1536748319959-kah6f9i1-1" style="height:250px; width:900px; margin: auto; margin-bottom: 2%;">
# <script>
#         googletag.cmd.push(function() {
#           //News banner for desktop
#           var slotIdWeb = 'div-gpt-ad-1536748319959-kah6f9i1-1';
#           var slot = googletag.defineSlot('/142919096/inshorts_website_900x250', [900, 250], slotIdWeb)
#           .addService(googletag.pubads())
#           .setCollapseEmptyDiv(true,true);
#
#           googletag.display('div-gpt-ad-1536748319959-kah6f9i1-1');
#           googletag.pubads().refresh([slot]);
#         });
#       </script>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/ill-be-more-happy-if-you-call-me-ravindra-jadeja-jadeja-as-bhogle-calls-him-sir-1620185035917" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="I'll be more happy if you call me Ravindra Jadeja: Jadeja as Bhogle calls him 'Sir'" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/5_wed/img_1620184603220_741.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/5_wed/img_1620184603220_741.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/ill-be-more-happy-if-you-call-me-ravindra-jadeja-jadeja-as-bhogle-calls-him-sir-1620185035917" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'I'll%20be%20more%20happy%20if%20you%20call%20me%20Ravindra%20Jadeja%3A%20Jadeja%20as%20Bhogle%20calls%20him%20'Sir')' });" style="color:#44444d!important">
# <span itemprop="headline">I'll be more happy if you call me Ravindra Jadeja: Jadeja as Bhogle calls him 'Sir'</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news
</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The ICC is in talks with the Emirates Cricket Board regarding hosting of the T20 World Cup, which is set to be played in India in October-November, in UAE, a report has claimed. "An announcement to this effect is likely to be made in the next two weeks," a source was quoted as saying. Meanwhile, IPL 2021 has been suspended. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/icc-in-talks-with-emirates-cricket-board-to-shift-t20-wc-from-india-to-uae-report-1620127865680"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-05-04T11:31:05.000Z" itemprop="dateModified">05:01 pm</span> on <span class="date">04 May</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.sportskeeda.com/amp/cricket/news-india-danger-losing-rights-host-t20-world-cup-reports?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Sportskeeda' });" target="_blank">Sportskeeda</a></div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/hope-all-overseas-players-can-find-a-way-back-to-their-families-vaughan-1620128124348" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="Hope all overseas players can find a way back to their families: Vaughan" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/4_tue/img_1620125748932_81.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2021/05_may/4_tue/img_1620125748932_81.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/hope-all-overseas-players-can-find-a-way-back-to-their-families-vaughan-1620128124348" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Hope%20all%20overseas%20players%20can%20find%20a%20way%20back%20to%20their%20families%3A%20Vaughan)' });" style="color:#44444d!important">
# <span itemprop="headline">Hope all overseas players can find a way back to their families: Vaughan</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/hope-all-overseas-players-can-find-a-way-back-to-their-families-vaughan-1620128124348"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-05-04T11:35:24.000Z" itemprop="datePublished">05:05 pm</span> on <span clas="date">04 May 2021,Tuesday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Former England captain Michael Vaughan has termed the suspension of the IPL 2021 as a "sensible decision" after four players tested positive inside its bio-secure bubble. "Hope everyone stays safe in India and all the overseas players can find a way back to there families," he tweeted. Several countries, including Australia, have banned direct flights from India. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/hope-all-overseas-players-can-find-a-way-back-to-their-families-vaughan-1620128124348"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2021-05-04T11:35:24.000Z" itemprop="dateModified">05:05 pm</span> on <span class="date">04 May</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://twitter.com/MichaelVaughan/status/1389518140510543874?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Twitter' });" target="_blank">Twitter</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2021</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "w5is7k6i-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls = ['https://inshorts.com/en/read/sports',
        'https://inshorts.com/en/read/technology',
        'https://inshorts.com/en/read/science']

def build_dataset(urls):

  news_data = []
  for url in urls:
    news_category = url.split('/')[-1]
    data = requests.get(url)
    soup = BeautifulSoup(data.content)   


    news_articles = [{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                      'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                      'news_category':news_category}

                     
                       for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                                 soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)                  

  df = pd.DataFrame(news_data)
  df = df[['news_headline','news_article','news_category']]
  return df

# %%
df = build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  IPL 2021 suspended indefinitely: BCCI Vice-Pre...  ...        sports
# 1  Prakash Padukone hospitalised after testing po...  ...        sports
# 2  CSK member reveals Dhoni delayed return, says ...  ...        sports
# 3  Ex-Australia cricketer MacGill kidnapped in Sy...  ...        sports
# 4  Fan spots ex-footballer's 'daughter's face' in...  ...        sports
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/HARBAL-DEEP-SIHU/SENTIMENTAL-ANALYSIS/main/news.csv")
df
# Out:
#                                         news_headline  ... news_category
# 0   IPL 2021 suspended indefinitely: BCCI Vice-Pre...  ...        sports
# 1   Prakash Padukone hospitalised after testing po...  ...        sports
# 2   CSK member reveals Dhoni delayed return, says ...  ...        sports
# 3   Ex-Australia cricketer MacGill kidnapped in Sy...  ...        sports
# 4   Fan spots ex-footballer's 'daughter's face' in...  ...        sports
# 5   Police launch raids to locate Sushil for quest...  ...        sports
# 6   24-yr-old wrestler beaten to death in Delhi, S...  ...        sports
# 7   SRH's Wriddhiman Saha, DC's Amit Mishra test C...  ...        sports
# 8   Bangladesh Cricket Board share 'insensitive' p...  ...        sports
# 9   I'll be more happy if you call me Ravindra Jad...  ...        sports
# 10  How about you take your jet & witness bodies o...  ...        sports
# 11  Video shows ambulance being stopped for IPL co...  ...        sports
# 12  How COVID-19 entered IPL bubble is very diffic...  ...        sports
# 13  Will do everything in power to arrange safe pa...  ...        sports
# 14  World's oldest person pulls out of Tokyo Olymp...  ...        sports
# 15  CSK's Behrendorff donates to UNICEF Australia'...  ...        sports
# 16  I hope IPL returns stronger when world is what...  ...        sports
# 17  Hope all overseas players can find a way back ...  ...        sports
# 18  Never understood criticism that came Jadeja's ...  ...        sports
# 19  We're in direct contact with BCCI: Cricket Aus...  ...        sports
# 20  PUBG to relaunch in India as 'Battlegrounds Mo...  ...    technology
# 21  Jeff Bezos sells $2.5 bn of Amazon shares in h...  ...    technology
# 22  Melinda French Gates won't change her name aft...  ...    technology
# 23  SpaceX Starship lands without exploding in 5th...  ...    technology
# 24  Bill Gates' company Cascade transfers ₹13,300 ...  ...    technology
# 25  Last week was terrible: US tech firm's CEO aft...  ...    technology
# 26  Donald Trump's Facebook ban upheld by Facebook...  ...    technology
# 27  Google adopts hybrid workweek, 20% staff to wo...  ...    technology
# 28  Man asks Google Support for help, ends up help...  ...    technology
# 29  American rapper Meek Mill buys over 92,000 Dog...  ...    technology
# 30  They must pay a political price: Trump after F...  ...    technology
# 31  Bitcoin inflows hit $441 million in last week ...  ...    technology
# 32  Bitcoin makes up 3% of my portfolio: 'Shark Ta...  ...    technology
# 33  Consumers sue Sony for limiting game purchases...  ...    technology
# 34  40% consumers plan to use crypto next year: Ma...  ...    technology
# 35  We want to be world's cryptocurrency mining ca...  ...    technology
# 36  Galaxy Digital to buy BitGo in crypto sector's...  ...    technology
# 37  WallStreetBets members targeted in $2 mn crypt...  ...    technology
# 38  Blue Origin to launch 1st human spaceflight in...  ...    technology
# 39  If Dogecoin is stupid, it shouldn't be worth $...  ...    technology
# 40  1st molecular images of B.1.1.7 COVID-19 mutat...  ...       science
# 41  There's no unique Andhra COVID-19 strain which...  ...       science
# 42  Jeff Bezos' Blue Origin to sell tickets for sp...  ...       science
# 43  SpaceX Starship lands without exploding in 5th...  ...       science
# 44  SpaceX returns 4 astronauts in rare night spla...  ...       science
# 45  Why did SpaceX Crew-1 astronauts land in the d...  ...       science
# 46  Astronaut's pic of Egypt's Great Pyramid, take...  ...       science
# 47  New type of pumpkin toadlet with glowing bones...  ...       science
# 48  World's first pregnant Egyptian mummy discover...  ...       science
# 49  ISS shares 4 pics of 'Super Moon' as seen from...  ...       science
# 50  Chinese rocket debris travelling at 29,000 kmp...  ...       science
# 51  Stranded deep-sea mining robot rescued from Pa...  ...       science
# 52  Blue Origin to launch 1st human spaceflight in...  ...       science
# 53  Mining robot stranded on Pacific Ocean floor i...  ...       science
# 54  NASA suspends SpaceX's $2.9 billion moon lande...  ...       science
# 55  Wine that spent 1 yr in orbit aboard space sta...  ...       science
# 56  SpaceX launches 60 satellites in its 10th Star...  ...       science
# 57  SpaceX launches another 60 Starlink satellites...  ...       science
# 58  How are the SpaceX Crew-1 & Crew-2 Dragon caps...  ...       science
# 59  SpaceX to attempt 1st US astronauts splashdown...  ...       science
#
# [60 rows x 3 columns]

# %%
import nltk 
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')


stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
# Remove HTML Tag
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text = soup.get_text()
  return new_text
  
html_tag('<html><h2> Some important info </h2></html>')
# Out:
# ' Some important info '

# %%
# Expand Contractions
# !pip install contractions
import contractions
def con(text):
  expand = contractions.fix(text)
  return expand
  
con(" y'all can't expand I'd think")
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.7/dist-packages (0.0.48)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.7/dist-packages (from contractions) (0.0.21)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (1.4.2)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.7/dist-packages (from textsearch>=0.0.21->contractions) (0.2.0)
# ' you all can not expand I would think'

# %%
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9\s]'
  text = re.sub(pattern,'' ,text)
  return text

remove_sp('Well this was good! but how did you do it? ')
# Out:
# 'Well this was good but how did you do it '

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in stopword_list]
  filtered_text = ''.join(filtered_tokens)
  return filtered_text

# %%
remove_stopwords('The , and  ,if not then what and how')
# Out:
# 'The,,not'

# %%
# 1. Lower Case
# 2. HTML Tags
# 3. Contractions
# 4. Special Characters
# 5. Stop Words

df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())


df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)

df.head()
# Out:
#                                        news_headline  ... news_category
# 0  ipl2021suspendedindefinitelybccivicepresidentr...  ...        sports
# 1  prakashpadukonehospitalisedtestingpositivecoro...  ...        sports
# 2  cskmemberrevealsdhonidelayedreturnsayslastleav...  ...        sports
# 3  exaustraliacricketermacgillkidnappedsydneygirl...  ...        sports
# 4  fanspotsexfootballersdaughtersfacecloudsdeaths...  ...        sports
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
 df.head()
# Out:
#                                        news_headline  ... compound
# 0  ipl2021suspendedindefinitelybccivicepresidentr...  ...      0.0
# 1  prakashpadukonehospitalisedtestingpositivecoro...  ...      0.0
# 2  cskmemberrevealsdhonidelayedreturnsayslastleav...  ...      0.0
# 3  exaustraliacricketermacgillkidnappedsydneygirl...  ...      0.0
# 4  fanspotsexfootballersdaughtersfacecloudsdeaths...  ...      0.0
#
# [5 rows x 4 columns]
